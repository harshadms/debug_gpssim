# %%
import pandas as pd
import matplotlib.pyplot as plt

nodelay = pd.read_csv("./nodelay_prange",names=['rate'])
delay = pd.read_csv("./delay_prange",names=['rate'])

# %%
plt.plot(nodelay)
plt.plot(delay)

# %%
from hms_utils import *

Geo.get_destination([42,-72], 4e6, 90)
